# %% [markdown]
# # Mi primer codigo
# ## mi primer cuaderno de jupyter
# ### estoy siguiendo el tutorial en apartado de primeros pasos
# ![Imagen](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTihnERzbk9IfaFv94k1RaolRZCbK2YAKH9KvxXQfREKg&s=10)

# %%
print("Hola Mundo")
x = 10
# Out:
# Hola Mundo

# %%
print("entre cajas anda el código")
print(x)
# Out:
# entre cajas anda el código
# 10
